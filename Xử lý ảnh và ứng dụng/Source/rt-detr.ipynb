# %%
# !pip install ultralytics

# %%
from ultralytics import RTDETR

# %%
model = RTDETR("rtdetr-l.pt")
results = model.train(batch = 32, epochs = 100, data = "/kaggle/input/data-cs406/datasets.yaml" , device = [0,1])
