# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import torch
print(torch.cuda.is_available())

# %%
model = YOLO('yolov5m.pt') 

result = model.train(
    data="/kaggle/input/data-cs406/datasets.yaml", 
    epochs=50,                                   
    device='0',                                  
    batch=8,                                     
    imgsz=640,                                     
    rect=True                                      
)

# %%
import os 
os.listdir("/kaggle/working/")
